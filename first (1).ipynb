# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/train.csv")

# %%
df.head(10)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
# 5           1859     0          0.5         1   3       0          22    0.7
# 6           1821     0          1.7         0   4       1          10    0.8
# 7           1954     0          0.5         1   0       0          24    0.8
# 8           1445     1          0.5         0   0       0          53    0.7
# 9            509     1          0.6         1   2       1           9    0.1
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
data=df.columns
print(data)
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
x=[ 'battery_power',  'clock_speed',  'fc', 'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc',
       'px_height', 'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time',
       'touch_screen']

# %%
for i in x:
    percentile25 = df[i].quantile(0.25)
    percentile75 = df[i].quantile(0.75)
    iqr = percentile75 - percentile25
    max_value = percentile75 + 1.5 * iqr
    min_value = percentile25 - 1.5 * iqr

    new_df = df[(df[i] > max_value) | (df[i] < min_value)]

    sns.boxplot(data=new_df[i], showfliers=True)
    plt.title(f'Boxplot for {i} with outliers')
    plt.show()

# %%
avg_ram = df.groupby('price_range')['ram'].mean()
plt.figure(figsize=(10, 6))
plt.bar(avg_ram.index, avg_ram.values, color=['r', 'g', 'b', 'y'])
plt.xlabel('Price Range')
plt.ylabel('Average RAM (GB)')
plt.title('Variation of RAM with respect to Mobile Price Range')
plt.xticks(avg_ram.index, labels=['Low', 'Mid-Low', 'Mid-High', 'High'])
plt.grid(True)
plt.show()

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
print(x.shape)
y.shape
# Out:
# (2000, 20)
# (2000,)

# %% [markdown]
# splitting the data in train and test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print("Shape of x_train:", x_train.shape)
print("Shape of x_test:", x_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of x_train: (1600, 20)
# Shape of x_test: (400, 20)
# Shape of y_train: (1600,)
# Shape of y_test: (400,)

# %% [markdown]
# model importing

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [markdown]
# model building and training

# %% [markdown]
# random forest

# %%
model_RandomForestClassifier=RandomForestClassifier()
model_RandomForestClassifier.fit(x_train,y_train)
prediction=model_RandomForestClassifier.predict(x_test)
acc=accuracy_score(y_test,prediction)
report=classification_report(y_test,prediction)
print(f"accuracy:{acc}")
print(report)

# %%
con_mat=confusion_matrix(y_test,prediction)
plt.figure(figsize=(6,5))
sns.heatmap(con_mat,annot=True,cmap='Blues')
plt.title('confusion matrix-random forest classifier')
plt.xlabel('predicted label')
plt.ylabel('True label')
plt.show()

# %% [markdown]
# knn

# %%
model_KNeighborsClassifier=KNeighborsClassifier()
model_KNeighborsClassifier.fit(x_train,y_train)
prediction=model_KNeighborsClassifier.predict(x_test)
acc=accuracy_score(y_test,prediction)
report=classification_report(y_test,prediction)
print(f"accuracy:{acc}")
print(report)

# %%
con_mat=confusion_matrix(y_test,prediction)
plt.figure(figsize=(6,6))
sns.heatmap(con_mat,annot=True,cmap='Blues')
plt.title('confusion matrix-KNN classsifier')
plt.xlabel('predicted label')
plt.ylabel('True labels')
plt.show()

# %% [markdown]
# Decision-tree-classifier

# %%
model_DecisionTreeClassifier=DecisionTreeClassifier()
model_DecisionTreeClassifier.fit(x_train,y_train)
prediction=model_DecisionTreeClassifier.predict(x_test)
acc=accuracy_score(y_test,prediction)
report=classification_report(y_test,prediction)
print(f"accuracy:{acc}")
print(report)

# %%
con_mat=confusion_matrix(y_test,prediction)
plt.figure(figsize=(6,6))
sns.heatmap(con_mat,annot=True,cmap='Blues')
plt.title('confusion matrix-decision tree classifier')
plt.xlabel('predicted label')
plt.ylabel('true label')
plt.show()

# %% [markdown]
# logistic regression

# %%
con_mat=confusion_matrix(y_test,prediction)
plt.figure(figsize=(6,6))
sns.heatmap(con_mat,annot=True,cmap='Blues')
plt.title('confusion matrix-logistic regression')
plt.xlabel('predicted label')
plt.ylabel('true label')
plt.show()

# %%
model_svm=SVC()
model_svm.fit(x_train,y_train)
prediction=model_svm.predict(x_test)
acc=accuracy_score(y_test,prediction)
report=classification_report(y_test,prediction)
print(f"accuracy:{acc}")
print(report)
# Out:
# accuracy:0.965
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99       105
#            1       0.95      0.99      0.97        91
#            2       0.94      0.95      0.94        92
#            3       0.98      0.95      0.96       112
#
#     accuracy                           0.96       400
#    macro avg       0.96      0.97      0.96       400
# weighted avg       0.97      0.96      0.97       400

# %%
df_test = pd.read_csv('/content/testdata.csv')
df_test.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
feat = df_test.iloc[:,1:]
feat
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 1              841     1          0.5         1   4       1          61
# 2             1807     1          2.8         0   1       0          27
# 3             1546     0          0.5         1  18       1          25
# 4             1434     0          1.4         0  11       1          49
# ..             ...   ...          ...       ...  ..     ...         ...
# 995           1700     1          1.9         0   0       1          54
# 996            609     0          1.8         1   0       0          13
# 997           1185     0          1.4         0   1       1           8
# 998           1533     1          0.5         1   0       0          50
# 999           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
arr = np.array([1043, 1, 1.8, 1, 14, 0, 5, 0.1, 193, 3, 16, 226, 1412, 3476, 12, 7, 2, 0, 1, 0])
arr = arr.reshape(1, -1)  # Reshape the array
pred = model_svm.predict(arr)  # Assuming model_svm is your trained SVM model

pred  # Assuming you want to see the prediction
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 1, 3, 0, 3, 3, 0, 0, 2, 0, 2, 1, 3, 2, 1, 3,
#        1, 1, 3, 0, 2, 0, 3, 0, 2, 0, 3, 0, 1, 1, 3, 1, 2, 1, 1, 2, 0, 0,
#        0, 1, 0, 3, 1, 2, 1, 0, 3, 0, 3, 1, 3, 1, 1, 3, 3, 3, 0, 1, 1, 1,
#        1, 3, 1, 2, 1, 2, 2, 3, 3, 0, 2, 0, 2, 3, 0, 3, 3, 0, 3, 0, 3, 1,
#        3, 0, 1, 2, 2, 1, 2, 2, 0, 2, 1, 2, 1, 0, 0, 3, 0, 2, 0, 1, 2, 3,
#        3, 3, 1, 3, 3, 3, 3, 2, 3, 0, 0, 3, 2, 1, 2, 0, 3, 2, 3, 1, 0, 2,
#        2, 1, 3, 1, 1, 0, 3, 2, 1, 2, 1, 2, 2, 3, 3, 3, 2, 3, 2, 3, 1, 0,
#        3, 2, 3, 3, 3, 3, 2, 2, 3, 3, 3, 3, 1, 0, 3, 0, 0, 0, 2, 1, 0, 1,
#        0, 0, 1, 2, 1, 0, 0, 1, 1, 2, 2, 1, 0, 0, 0, 1, 0, 3, 1, 0, 2, 2,
#        2, 3, 1, 1, 3, 2, 3, 2, 2, 1, 0, 0, 1, 2, 0, 2, 3, 3, 0, 2, 0, 3,
#        2, 3, 3, 1, 0, 1, 0, 3, 0, 1, 0, 2, 2, 1, 2, 0, 3, 0, 3, 1, 2, 0,
#        0, 2, 1, 3, 3, 3, 1, 1, 3, 0, 0, 2, 3, 3, 1, 3, 1, 1, 3, 2, 1, 2,
#        3, 3, 3, 1, 0, 1, 2, 3, 1, 1, 3, 2, 0, 3, 0, 0, 2, 0, 0, 3, 2, 3,
# ...
